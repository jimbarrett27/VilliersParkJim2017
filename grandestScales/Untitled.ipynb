# %%
import numpy as np
import matplotlib.pyplot as plot

# %matplotlib inline

import seaborn as sb

# %%
data = np.loadtxt('/home/jbarrett/phd/carma/talks/aldebaran.dat')

# %%
plot.errorbar(data[:,0],data[:,1],data[:,2],fmt='.')
plot.xlabel('Julian Days',size=15)
plot.ylabel(r'Radial Velocity ($ms^{-1}$)',size=15)

plot.savefig('aldebaranData.png',dpi=400)
